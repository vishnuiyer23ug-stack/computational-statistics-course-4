# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuiyer23ug-stack/computational-statistics-course-4/blob/main/Class_01_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("Press Shift+Enter to run and create a new block.")
# Out:
# Press Shift+Enter to run and create a new block.

# %% [markdown]
# 1.   List item
# 2.   $\frac{5}{4}$

# %% [markdown]
# Hit Alt+t to add in a text cell, and use Alt+c to add in a code cell.

# %%
a = 5
b= 10
c = a+b
c
# Out:
# 15

# %%
import matplotlib.pyplot as plt #now matplotlib is recognised as plt

# %%
ad_expense = [20,10,50,21,31]
sales = [200,320,140,260,100]
plt.plot(ad_expense, sales)
